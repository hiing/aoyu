# %% [markdown]
# <a href="https://colab.research.google.com/github/hiing/aoyu/blob/master/Z_Image_Turbo_4bit_jupyter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -U git+https://github.com/huggingface/diffusers git+https://github.com/Disty0/sdnq
# Out:
# ...
#   Cloning https://github.com/huggingface/diffusers to /tmp/pip-req-build-pg7sm9u1
#   Running command git clone --filter=blob:none --quiet https://github.com/huggingface/diffusers /tmp/pip-req-build-pg7sm9u1
#   Resolved https://github.com/huggingface/diffusers to commit a1f36ee3ef4ae1bf98bd260e539197259aa981c1
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Cloning https://github.com/Disty0/sdnq to /tmp/pip-req-build-3qsy9wt0
#   Running command git clone --filter=blob:none --quiet https://github.com/Disty0/sdnq /tmp/pip-req-build-3qsy9wt0
#   Resolved https://github.com/Disty0/sdnq to commit 3fce0ac6f685861b21f2347f4879a8c1a4c2ec73
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...

# %%
import torch
import diffusers
from sdnq import SDNQConfig # import sdnq to register it into diffusers and transformers
from sdnq.loader import apply_sdnq_options_to_model

pipe = diffusers.ZImagePipeline.from_pretrained("Disty0/Z-Image-Turbo-SDNQ-uint4-svd-r32", torch_dtype=torch.float16, device_map="cuda")
pipe.transformer = apply_sdnq_options_to_model(pipe.transformer, use_quantized_matmul=True)
pipe.text_encoder = apply_sdnq_options_to_model(pipe.text_encoder, use_quantized_matmul=True)
# Out:
# Loading pipeline components...:   0%|          | 0/5 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# OutOfMemoryError                          Traceback (most recent call last)
# /tmp/ipython-input-1291802179.py in <cell line: 0>()
#       4 from sdnq.loader import apply_sdnq_options_to_model
#       5
# ----> 6 pipe = diffusers.ZImagePipeline.from_pretrained("Disty0/Z-Image-Turbo-SDNQ-uint4-svd-r32", torch_dtype=torch.float32, device_map="cuda")
#       7 pipe.transformer = apply_sdnq_options_to_model(pipe.transformer, use_quantized_matmul=True)
#       8 pipe.text_encoder = apply_sdnq_options_to_model(pipe.text_encoder, use_quantized_matmul=True)
#
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_validators.py in _inner_fn(*args, **kwargs)
#     112             kwargs = smoothly_deprecate_use_auth_token(fn_name=fn.__name__, has_token=has_token, kwargs=kwargs)
#     113
# --> 114         return fn(*args, **kwargs)
# ...

# %%
prompt = "亚洲长发美女"
image = pipe(
    prompt=prompt,
    height=1024,
    width=1024,
    num_inference_steps=9,
    guidance_scale=0.0,
    generator=torch.manual_seed(42),
).images[0]
display(image)
# Out:
# ---------------------------------------------------------------------------
# OutOfMemoryError                          Traceback (most recent call last)
# /tmp/ipython-input-383057375.py in <cell line: 0>()
#       1 prompt = "亚洲长发美女"
# ----> 2 image = pipe(
#       3     prompt=prompt,
#       4     height=1024,
#       5     width=1024,
#
# /usr/local/lib/python3.12/dist-packages/torch/utils/_contextlib.py in decorate_context(*args, **kwargs)
#     118     def decorate_context(*args, **kwargs):
#     119         with ctx_factory():
# --> 120             return func(*args, **kwargs)
#     121
#     122     return decorate_context
#
# ...
